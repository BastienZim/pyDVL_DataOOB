# %%
! python3 -m pip install synthcity
# Out:
# Requirement already satisfied: synthcity in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (0.2.9)
# Requirement already satisfied: cloudpickle in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (2.2.1)
# Requirement already satisfied: tsai; python_version > "3.7" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.3.7)
# Requirement already satisfied: opacus>=1.3 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (1.4.0)
# Requirement already satisfied: monai in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (1.2.0)
# Requirement already satisfied: loguru in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.7.2)
# Requirement already satisfied: decaf-synthetic-data>=0.1.6 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.1.6)
# Requirement already satisfied: nflows>=0.14 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.14)
# Requirement already satisfied: pycox in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.2.3)
# Requirement already satisfied: redis in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (5.0.0)
# Requirement already satisfied: scipy in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (1.10.1)
# Requirement already satisfied: shap in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.42.1)
# Requirement already satisfied: pandas<2,>=1.4 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (1.5.3)
# Requirement already satisfied: lifelines!=0.27.5,>=0.27 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.27.8)
# Requirement already satisfied: optuna>=3.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (3.3.0)
# Requirement already satisfied: tqdm in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (4.66.1)
# Requirement already satisfied: xgbse in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.2.3)
# Requirement already satisfied: numpy<1.24,>=1.20 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (1.23.5)
# Requirement already satisfied: scikit-learn>=1.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (1.3.1)
# Requirement already satisfied: pykeops in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (2.1.2)
# Requirement already satisfied: pydantic<2.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (1.10.12)
# Requirement already satisfied: geomloss in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.2.6)
# Requirement already satisfied: torch<2.0,>=1.10.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (1.13.1)
# Requirement already satisfied: fflows in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.0.3)
# Requirement already satisfied: xgboost<2.0.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (1.7.6)
# Requirement already satisfied: pgmpy in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.1.23)
# Requirement already satisfied: arfpy in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from synthcity) (0.1.1)
# Requirement already satisfied: fastai>=2.7.12 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tsai; python_version > "3.7"->synthcity) (2.7.12)
# Requirement already satisfied: pyts>=0.12.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tsai; python_version > "3.7"->synthcity) (0.13.0)
# Requirement already satisfied: imbalanced-learn>=0.8.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tsai; python_version > "3.7"->synthcity) (0.11.0)
# Requirement already satisfied: psutil>=5.4.8 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tsai; python_version > "3.7"->synthcity) (5.9.5)
# Requirement already satisfied: opt-einsum>=3.3.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from opacus>=1.3->synthcity) (3.3.0)
# Requirement already satisfied: pytorch-lightning<2.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from decaf-synthetic-data>=0.1.6->synthcity) (1.9.5)
# Requirement already satisfied: torchtext>=0.10 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from decaf-synthetic-data>=0.1.6->synthcity) (0.15.2)
# Collecting networkx<3.0,>=2.0
#   Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: tensorboard in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from nflows>=0.14->synthcity) (2.14.0)
# Requirement already satisfied: matplotlib in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from nflows>=0.14->synthcity) (3.7.3)
# Requirement already satisfied: h5py>=2.9.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pycox->synthcity) (3.9.0)
# Requirement already satisfied: torchtuples>=0.2.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pycox->synthcity) (0.2.2)
# Requirement already satisfied: numba>=0.44 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pycox->synthcity) (0.58.0)
# Requirement already satisfied: py7zr>=0.11.3 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pycox->synthcity) (0.20.6)
# Requirement already satisfied: requests>=2.22.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pycox->synthcity) (2.31.0)
# Requirement already satisfied: feather-format>=0.4.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pycox->synthcity) (0.4.1)
# Requirement already satisfied: async-timeout>=4.0.2; python_full_version <= "3.11.2" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from redis->synthcity) (4.0.3)
# Requirement already satisfied: slicer==0.0.7 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from shap->synthcity) (0.0.7)
# Requirement already satisfied: packaging>20.9 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from shap->synthcity) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pandas<2,>=1.4->synthcity) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pandas<2,>=1.4->synthcity) (2023.3.post1)
# Requirement already satisfied: autograd-gamma>=0.3 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from lifelines!=0.27.5,>=0.27->synthcity) (0.5.0)
# Requirement already satisfied: autograd>=1.5 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from lifelines!=0.27.5,>=0.27->synthcity) (1.6.2)
# Requirement already satisfied: formulaic>=0.2.2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from lifelines!=0.27.5,>=0.27->synthcity) (0.6.4)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from optuna>=3.1->synthcity) (2.0.21)
# Requirement already satisfied: colorlog in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from optuna>=3.1->synthcity) (6.7.0)
# Requirement already satisfied: PyYAML in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from optuna>=3.1->synthcity) (6.0.1)
# Requirement already satisfied: cmaes>=0.10.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from optuna>=3.1->synthcity) (0.10.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from optuna>=3.1->synthcity) (1.12.0)
# Requirement already satisfied: joblib>=0.15.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from xgbse->synthcity) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from scikit-learn>=1.0->synthcity) (3.2.0)
# Requirement already satisfied: pybind11 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pykeops->synthcity) (2.11.1)
# Requirement already satisfied: keopscore==2.1.2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pykeops->synthcity) (2.1.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pydantic<2.0->synthcity) (4.8.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from torch<2.0,>=1.10.0->synthcity) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from torch<2.0,>=1.10.0->synthcity) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from torch<2.0,>=1.10.0->synthcity) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from torch<2.0,>=1.10.0->synthcity) (11.7.99)
# Requirement already satisfied: statsmodels in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pgmpy->synthcity) (0.14.0)
# Requirement already satisfied: pyparsing in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pgmpy->synthcity) (3.1.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (1.0.3)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (0.0.7)
# Requirement already satisfied: spacy<4 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (3.6.1)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (1.5.29)
# Requirement already satisfied: torchvision>=0.8.2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (0.15.2)
# Requirement already satisfied: pip in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (20.0.2)
# Requirement already satisfied: pillow>6.0.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (9.3.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (1.2.0)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (0.9.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (2023.9.1)
# Requirement already satisfied: torchdata==0.6.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from torchtext>=0.10->decaf-synthetic-data>=0.1.6->synthcity) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (0.41.2)
# Requirement already satisfied: setuptools>=41.0.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (68.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (3.4.4)
# Requirement already satisfied: grpcio>=1.48.2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (1.58.0)
# Requirement already satisfied: protobuf>=3.19.6 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (4.24.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (2.23.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (2.3.7)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (0.7.1)
# Requirement already satisfied: absl-py>=0.4 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from tensorboard->nflows>=0.14->synthcity) (2.0.0)
# Requirement already satisfied: cycler>=0.10 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from matplotlib->nflows>=0.14->synthcity) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from matplotlib->nflows>=0.14->synthcity) (6.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from matplotlib->nflows>=0.14->synthcity) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from matplotlib->nflows>=0.14->synthcity) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from matplotlib->nflows>=0.14->synthcity) (4.42.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.9" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from numba>=0.44->pycox->synthcity) (6.8.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from numba>=0.44->pycox->synthcity) (0.41.0)
# Requirement already satisfied: pyppmd<1.1.0,>=0.18.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from py7zr>=0.11.3->pycox->synthcity) (1.0.0)
# Requirement already satisfied: pybcj>=0.6.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from py7zr>=0.11.3->pycox->synthcity) (1.0.1)
# Requirement already satisfied: pyzstd>=0.14.4 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from py7zr>=0.11.3->pycox->synthcity) (0.15.9)
# Requirement already satisfied: texttable in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from py7zr>=0.11.3->pycox->synthcity) (1.6.7)
# Requirement already satisfied: pycryptodomex>=3.6.6 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from py7zr>=0.11.3->pycox->synthcity) (3.19.0)
# Requirement already satisfied: inflate64>=0.3.1; python_version > "3.6" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from py7zr>=0.11.3->pycox->synthcity) (0.3.1)
# Requirement already satisfied: brotli>=1.0.9; platform_python_implementation == "CPython" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from py7zr>=0.11.3->pycox->synthcity) (1.1.0)
# Requirement already satisfied: multivolumefile>=0.2.3 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from py7zr>=0.11.3->pycox->synthcity) (0.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from requests>=2.22.0->pycox->synthcity) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from requests>=2.22.0->pycox->synthcity) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from requests>=2.22.0->pycox->synthcity) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from requests>=2.22.0->pycox->synthcity) (3.4)
# Requirement already satisfied: pyarrow>=0.4.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from feather-format>=0.4.0->pycox->synthcity) (13.0.0)
# Requirement already satisfied: six>=1.5 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas<2,>=1.4->synthcity) (1.16.0)
# Requirement already satisfied: future>=0.15.2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from autograd>=1.5->lifelines!=0.27.5,>=0.27->synthcity) (0.18.3)
# Requirement already satisfied: interface-meta>=1.2.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from formulaic>=0.2.2->lifelines!=0.27.5,>=0.27->synthcity) (1.3.0)
# Requirement already satisfied: graphlib-backport>=1.0.0; python_version < "3.9" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from formulaic>=0.2.2->lifelines!=0.27.5,>=0.27->synthcity) (1.0.3)
# Requirement already satisfied: wrapt>=1.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from formulaic>=0.2.2->lifelines!=0.27.5,>=0.27->synthcity) (1.13.3)
# Requirement already satisfied: astor>=0.8 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from formulaic>=0.2.2->lifelines!=0.27.5,>=0.27->synthcity) (0.8.1)
# Requirement already satisfied: greenlet!=0.4.17; platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32"))))) in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from sqlalchemy>=1.3.0->optuna>=3.1->synthcity) (2.0.2)
# Requirement already satisfied: Mako in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from alembic>=1.5.0->optuna>=3.1->synthcity) (1.2.4)
# Requirement already satisfied: patsy>=0.5.2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from statsmodels->pgmpy->synthcity) (0.5.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (1.0.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (8.1.12)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (3.3.0)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (6.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (2.0.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (1.0.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (2.4.8)
# Requirement already satisfied: jinja2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (3.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (2.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (1.1.2)
# Requirement already satisfied: pathy>=0.10.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (0.10.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (3.8.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->nflows>=0.14->synthcity) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->nflows>=0.14->synthcity) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->nflows>=0.14->synthcity) (5.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard->nflows>=0.14->synthcity) (2.1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->nflows>=0.14->synthcity) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib->nflows>=0.14->synthcity) (3.17.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai>=2.7.12->tsai; python_version > "3.7"->synthcity) (8.1.7)
# Requirement already satisfied: attrs>=17.3.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>2021.06.0->pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (23.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>2021.06.0->pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>2021.06.0->pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>2021.06.0->pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>2021.06.0->pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (1.9.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nflows>=0.14->synthcity) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->nflows>=0.14->synthcity) (3.2.2)
# Installing collected packages: networkx
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
# Successfully installed networkx-2.8.8

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from pydvl.value import compute_data_oob
from pydvl.utils import Dataset, Utility, Scorer
from pydvl.reporting.scores import compute_removal_score
from pydvl.reporting.plots import shaded_mean_std, plot_best_worst, plot_best_worst_class_imbalance, compute_best_worst_scores, plot_methods_linreg
from pydvl.value.result import ValuationResult

from sklearn.datasets import load_iris, fetch_kddcup99, fetch_openml
import pandas as pd

# %%
import pandas as pd
from sklearn.datasets import load_iris

data = Dataset.from_sklearn(load_iris())

# %%
X,y = data.x_train, data.y_train

# %%
# synthcity absolute
import synthcity.logger as log
from synthcity.plugins import Plugins
from synthcity.plugins.core.dataloader import GenericDataLoader
# Out:
# [KeOps] Warning : Cuda libraries were not detected on the system ; using cpu only mode

# %%
# synthcity absolute
from synthcity.plugins import Plugins

Plugins().list()
# Out:
# [2023-09-22T17:28:06.389356+0200][70074][CRITICAL] module disabled: /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages/synthcity/plugins/generic/plugin_goggle.py
# [2023-09-22T17:28:07.637390+0200][70074][CRITICAL] load failed:
# GReaT is not installed. Please install it with pip install GReaT.
# Please be aware that GReaT is only available for python >= 3.9.
#
# [2023-09-22T17:28:07.640740+0200][70074][CRITICAL] load failed: module 'synthcity.plugins.generic.plugin_great' has no attribute 'plugin'
# [2023-09-22T17:28:07.650449+0200][70074][CRITICAL] module plugin_great load failed
# ['ddpm',
#  'privbayes',
#  'decaf',
#  'timevae',
#  'uniform_sampler',
#  'survae',
#  'radialgan',
#  'image_cgan',
#  'image_adsgan',
#  'adsgan',
#  'survival_nflow',
#  'bayesian_network',
#  'tvae',
#  'marginal_distributions',
#  'timegan',
#  'fflows',
#  'pategan',
#  'survival_ctgan',
#  'dummy_sampler',
#  'dpgan',
#  'rtvae',
#  'aim',
#  'ctgan',
#  'survival_gan',
#  'nflow',
#  'arf']

# %%
from sklearn.mixture import GaussianMixture

# %%
syn_model = Plugins().get("adsgan")
# Out:
# [2023-09-22T17:29:35.780632+0200][70074][CRITICAL] module disabled: /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages/synthcity/plugins/generic/plugin_goggle.py
# [2023-09-22T17:29:35.787681+0200][70074][CRITICAL] load failed: module 'synthcity.plugins.generic.plugin_great' has no attribute 'plugin'
# [2023-09-22T17:29:35.790933+0200][70074][CRITICAL] load failed: module 'synthcity.plugins.generic.plugin_great' has no attribute 'plugin'
# [2023-09-22T17:29:35.792762+0200][70074][CRITICAL] module plugin_great load failed

# %%
syn_model

# %%
# synthcity absolute
from synthcity.plugins import Plugins

syn_model = Plugins().get("adsgan")
loader = GenericDataLoader(
    X,
)
syn_model.fit(loader)
# Out:
# [2023-09-22T17:29:37.705666+0200][70074][CRITICAL] module disabled: /home/bastienzim/Documents/pyDVL_DataOOB/venv/lib/python3.8/site-packages/synthcity/plugins/generic/plugin_goggle.py
# [2023-09-22T17:29:37.713099+0200][70074][CRITICAL] load failed: module 'synthcity.plugins.generic.plugin_great' has no attribute 'plugin'
# [2023-09-22T17:29:37.717420+0200][70074][CRITICAL] load failed: module 'synthcity.plugins.generic.plugin_great' has no attribute 'plugin'
# [2023-09-22T17:29:37.722902+0200][70074][CRITICAL] module plugin_great load failed
#   4%|▍         | 399/10000 [02:06<50:43,  3.15it/s]

# %%
syn_model.generate(count=20)#.dataframe()
# Out:
#            0         1         2         3
# 0   5.744118  3.077127  3.262061  0.184592
# 1   5.738226  3.409170  1.137796  0.247733
# 2   6.210682  2.939403  4.712767  1.713686
# 3   6.347595  2.978323  5.170886  1.887413
# 4   6.341597  2.823523  4.864680  1.890787
# 5   6.682200  2.613717  5.218269  1.954887
# 6   6.495362  2.769848  4.955323  1.944609
# 7   6.418763  3.195445  4.808994  2.068136
# 8   6.499832  2.732377  5.086455  1.914482
# 9   6.028796  3.094103  4.821779  1.356058
# 10  4.764247  3.294699  4.620673  0.244386
# 11  5.807657  3.471215  4.485095  0.214973
# 12  5.705049  3.031910  4.629153  1.232073
# 13  5.671786  3.327249  4.512141  0.199219
# 14  6.352706  2.832607  4.985086  1.928399
# 15  6.397991  2.873841  4.959373  1.698160
# 16  5.801293  3.159491  4.606733  0.125561
# 17  6.833433  2.722042  5.136972  2.424705
# 18  6.532745  2.802655  4.767480  1.816342
# 19  6.530436  2.735175  5.085730  1.852043
